# %%
# import urllib.request as req
# import tarfile
# import os

# imdb_url = "http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz"

# save_filename = "aclImdb_v1.tar.gz"
# if not os.path.exists(save_filename):
#     req.urlretrieve(imdb_url, save_filename)
    
# imdb_folder = "aclImdb"
# if not os.path.exists(imdb_folder):
#     with tarfile.open(save_filename) as tar:
#         tar.extractall()

# %%
# import numpy as np
# import re

# def get_reviews(data_folder="/train"):
#     reviews = []
#     labels = []
#     for index,sentiment in enumerate(["/neg/", "/pos/"]):
#         path = imdb_folder + data_folder + sentiment
#         for filename in sorted(os.listdir(path)):
#             with open(path + filename, 'r') as f:
#                 review = f.read()
#                 review = review.lower()
#                 review = review.replace("<br />", " ")
#                 review = re.sub(r"[^a-z ]", " ", review)
#                 review = re.sub(r" +", " ", review)
#                 review = review.split(" ")
#                 reviews.append(review)
                
#                 label = [0, 0]
#                 label[index] = 1
#                 labels.append(label)
                
#     return reviews, np.array(labels)

# %%
# train_reviews, train_labels = get_reviews()
# print(len(train_reviews))
# print(train_reviews[0])
# print(train_labels[0])

# %%
Text = "I love the rain and the sun. It makes me feel whole and grown. Who knew that life was mysterious like your mom."

# %%
word_tokenize(Text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-ec81144236d1> in <module>
# ----> 1 word_tokenize(Text)
#
# NameError: name 'word_tokenize' is not defined

# %%
def tokenize_words():
    review_tokenized = []
    review = word_tokenize()
    reviews.append(review_tokenized)
    return review_tokenized

# %%
tokenize_words(Text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-68c772fe3c58> in <module>
# ----> 1 tokenize_words(Text)
#
# TypeError: tokenize_words() takes 0 positional arguments but 1 was given

# %%
import re
from contextlib import redirect_stdout
from io import StringIO

# %%
def token_to_words(str):
    f = StringIO()
    with redirect_stdout(f):
        for i in str:
            regex_of_word = re.findall('([\w]{0,})', i)
            regex_of_word = [x for x in regex_of_word if x is not '']
            for word in regex_of_word:
                print(regex_of_word)
        words = (f.getvalue()).split('\n')

# %%
exclude = set(['Mary', 'Jack', 'Jill', 'i', 'it'])

mod_example = []
for sentence in example:
    words = sentence.split()
    # Optionally sort out some words
    for word in words:
        if word in exclude:
            words.remove(word)
    mod_example.append('\'' + '\' \''.join(words) + '\'')

print mod_example

# %%
# from nltk.corpus import stopwords 
# from nltk.tokenize import word_tokenize

# text = "I love the rain and the sun. It makes me feel whole and grown. Who knew that life was mysterious like your mom."

# stop_words = set(stopwords.words('english')) 
# word_tokens = word_tokenize(text) 
# filtered_sentence = [w for w in word_tokens if not w in stop_words] 
  
# filtered_sentence = [] 
  

# # def tokenize_words():
# #     for wordings in Text:
# #         words = word_tokenize(wordings)
# #         for word in words:
# #             stop = stopwords.words('english')
# #             if word in stop:
# #                 words.remove(word)
# #         mod_example.append("\" + '\' \''.join(words) + '\'') 
        

# def tokenize_words():
#     for w in word_tokens: 
#         if w not in stop_words: 
#             filtered_sentence.append(w)
#     print(word_tokens)
#     print(filtered_sentence)

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize
import string 

text = "I love the rain and the sun. It makes me feel whole and grown. Who knew that life was mysterious like your mom."

stop_words = set(stopwords.words('english')) 
word_tokens = word_tokenize(text) 
filtered_sentence = [w for w in word_tokens if not w in stop_words] 
  
filtered_sentence = []

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
#CORRECT CODE 

stop_words = set(stopwords.words("english"))
punctuation = string.punctuation

def tokenize_words(text, stopwords, punctuation):
    text = text.lower() 
    text = text.replace("<br />", " ")
    text = re.sub(r"[^a-z ]", " ", text)
    text = re.sub(r" +", " ", text)
#     tokens = word_tokenize(text)
#     filtered = []
#     for w in tokens:
#         if w not in stopwords and w not in punctuation:
#             filtered.append(w)
    return text

# %%
import io 
import re
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
#word_tokenize accepts a string as an input, not a file. 
stop_words = set(stopwords.words('english')) 
# file1 = open("../test_neg.txt") 
# line = file1.read()# Use this to read file content as a stream: 
# words = line.split() 
# for r in words: 
#     if not r in stop_words: 
#         appendFile = open('filteredtext.txt','a') 
#         appendFile.write(" "+r) 
#         appendFile.close()
        
with open("../test_neg.txt") as readfile:
    for i in range(10):
        line = readfile.readline()
        filtered = tokenize_words(line, stop_words, string.punctuation)
        print(filtered)
# Out:
# alan rickman emma thompson give good performances with southern new orleans accents in this detective flick it s worth seeing for their scenes and rickman s scene with hal holbrook these three actors mannage to entertain us no matter what the movie it seems the plot for the movie shows potential but one gets the impression in watching the film that it was not pulled off as well as it could have been the fact that it is cluttered by a rather uninteresting subplot and mostly uninteresting kidnappers really muddles things the movie is worth a view if for nothing more than entertaining performances by rickman thompson and holbrook
# i have seen this movie and i did not care for this movie anyhow i would not think about going to paris because i do not like this country and its national capital i do not like to learn french anyhow because i do not understand their language why would i go to france when i rather go to germany or the united kingdom germany and the united kingdom are the nations i tolerate apparently the olsen twins do not understand the french language just like me therefore i will not bother the france trip no matter what i might as well stick to the united kingdom and meet single women and play video games if there is a video arcade that is all
# in los angeles the alcoholic and lazy hank chinaski matt dillon performs a wide range of non qualified functions just to get enough money to drink and gamble in horse races his primary and only objective is writing and having sexy with dirty women factotum is an uninteresting pointless and extremely boring movie about an irresponsible drunken vagrant that works a couple of days or weeks just to get enough money to buy spirits and gamble being immediately fired due to his reckless behavior in accordance with imdb this character would be the fictional alter ego of the author charles bukowski and based on this story i will certainly never read any of his novels honestly if the viewer likes this theme of alcoholic couples better off watching the touching and heartbreaking hector babenco s ironweed or marco ferreri s storie di ordinaria follia that is based on the life of the same writer my vote is four title brazil factotum sem destino factotum without destiny
# this film is bundled along with gli fumavano le colt lo chiamavano camposanto and both films leave a lot to be desired in the way of their dvd prints first both films are very dark occasionally making it hard to see exactly what s happening second neither film has subtitles and you are forced to watch a dubbed film though il prezzo del potere does seem to have a better dub personally i always prefer subtitles but for the non purists out there this isn t a problem these dvd problems however are not the fault of the original film makers just the indifferent package being marketed four decades later as for the film it s about the assassination of president garfield this is a major problem as van johnson looks about as much like garfield as judy garland in no way whatsoever does he look like garfield he s missing the beard has the wrong hair color and style and is just not even close in any way trust me on this i am an american history teacher and we are paid to know these sort of things the real life garfield was a civil war general and looked like the guys on the smith brothers cough drop boxes plus using some other actor to provide the voice for johnson in the dubbing is just surreal never before or since has van johnson sounded quite so macho he was a fine actor but certainly not a convincing general or macho president in addition to the stupid casting president garfield s death was in no way like this film it s obvious that the film makers are actually cashing in on the crazy speculation about conspiracies concerning the death of jfk not garfield garfield was shot in washington dc not dallas by a lone gunman with severe mental problems not a group of men with rifles however according to most experts what actually killed garfield over two months later were incompetent doctors who probed and probed and probed to retrieve a bullet to no avail and never bothered cleaning their hands or implements in the process in other words like george washington who was basically killed by repeated bloodletting when suffering with pneumonia he died due to malpractice in the movie they got nothing right whatsoever other than indeed president garfield was shot because the film bears almost no similarity to real history it s like a history lesson as taught from someone from another planet or someone with a severe brain injury why not also include ninjas fighting robots and the greek gods while you re at it aside from some decent acting and production values because the script is utter cow crap i don t recommend anyone watch it it s just a complete and utter mess
# i only comment on really very good films and on utter rubbish my aim is to help people who want to see great films to spend their time and money wisely i also want to stop people wasting their time on garbage and want to publicize the fact that the director producer of these garbage films can t get away with it for very long we will find out who you are and will vote with out feet and wallets this film clearly falls into the garbage category the director and writer is john shiban it s always a bad sign when the writer is also the director maybe he wants two pay cheques he shouldn t get any so remember the name john shiban and if you see anything else by him forget it i won t say anything about the plot others have already i am a little worried by how much the director likes to zoom in to the poor girl s face when she is crying and screaming these long duration shots are a little worrying and may say something about the state of mind of mr shiban maybe he should get psychiatric help enough already it s crap don t waste your time on it
# when you look at the cover and read stuff about it an entirely different type of movie comes to mind than what you get here then again maybe i read the summary for the other movie called mausolem instead as there were two movies of this title released about the same time with both featuring plots that had key elements in common however reading stuff about that movie here i know i saw this one and not that one and that movie is even less what one would imagine a movie with that title would be about i will be honest i expect more of a zombie type picture and you get that in this movie to some degree however there is more stuff involving the occult and strange powers as the opening scene of the people being taken away by the coroner at the beginning of the film will attest to the movie also has the old theme of kids going somewhere they do not belong to have some crazy party in this case it is in fact a mausoleum the other movie i do not think really has that key feature playing that prominent role in the movie and i see the score for this one is higher too still it was just not the movie i was expecting
# rollerskating vampires i m sorry but even for the s that s just way too cheesy to be remotely scary you can excuse the original the odd kitsch moment because it was parodying old movies and tv shows but that s been done once so the sequel needed to be a little less camp not even more outlandish plus the first movie had the presence of chris sarandon a man who could even make stalking discotheques in casual knitwear seem seductive that this one sorely lacks so there was no danger in anything that happened it just seemed silly admittedly i only saw this once when i was but by then already being a huge fan of the original i remember being disgusted to me there is no sequel to fright night just a tacky spoof that doesn t deserve any appraisal whatsoever
# technically abominable with audible pops between scenes and awesomely amateurish flesh requires a lot of patience to sit through and will probably turn off most viewers but the dialogue rings amazingly true and joe dallesandro who exposes his body in almost every scene also gives an utterly convincing performance a curio to be sure but the more polished trash made two years later is a definite step forward i suggest you watch that instead
# when hollywood is trying to grasp what an intelligent person is like they fail so miserably finding it hard putting words in the mouth of the purported genius right any genius walks around trying to rub in his superiority at every instance sure they hang out in bars and pick fights it s not like they are generalizing wildly autistic nerds who never have a tan plus if you are a genius you know all about math and history and politics and of course you re constantly up to date with current events and a thorough analysis of them coz these things like all go together n stuff y know plus you walk around with a smirk all the time you are just a smug son of a you know what that s how it is y all and of course you smoke like someone who never smoked before but you smoke coz it s like cool n stuff y know and you re different that is understood and of course you can fight you re a bully a bully who finds time to study books whenever he doesn t lift weights and whenever he doesn t smoke or drink beer because he follows a strict health regimen and you date a something college student minnie driver well i won t even comment matt damon team america has hit the nail on the head already this movie is a daydream of a beavis butthead type student in other words of them yeah that s what i would be like if i was a genius but stupid people and stupid authors in this case cannot imagine the lives of geniuses
# respected western auteur budd boetticher is woefully out of place with this choppy modern day cops and robbers story that suffers from a strong lack of emotional believability boetticher seems to have waived rehearsal time and settled for the first take as leads joe cotton and rhonda fleming put little effort into their roles delivering lines flatly and without energy mild mannered employee leon foggy poole works as an inside man on a bank job that goes bad and gets his wife killed in the process he escapes from prison and immediately sets out to kill the wife of the detective who killed his hundreds of cops are mobilized to keep him from getting to the home of the intended who has been moved to another location but wouldn t you know in the films final moments we have foggy trailing feet behind the victim who thought somehow that taking a bus back to the house was a sound move while a company of cops observe and bicker over what action to take sound preposterous you should see it it s all of that and more lucien ballard s camera work does a decent job of bringing noir to the suburbs but the editing is lackadaisical and shapeless and it drains the film of its suspense and pace as poole wendell corey is the best thing in the film managing to evoke great sympathy as he transitions from gentle soul to murderer these attributes aside killer uniformly fails in construction and execution making its message clear go western old budd

# %%
import pandas as pd

# %%
test_neg_path = "../test_neg.txt"
reviews = pd.read_table(test_neg_path, sep="\n", header=None, names=['Reviews'])
reviews.head()
# Out:
#                                              Reviews
# 0  Alan Rickman & Emma Thompson give good perform...
# 1  I have seen this movie and I did not care for ...
# 2  In Los Angeles, the alcoholic and lazy Hank Ch...
# 3  This film is bundled along with "Gli fumavano ...
# 4  I only comment on really very good films and o...

# %%
reviews['Reviews (filtered)'] = reviews['Reviews'].apply(tokenize_words, args=(stop_words, punctuation))

# %%
reviews.head()
# Out:
#                                              Reviews  \
# 0  Alan Rickman & Emma Thompson give good perform...
# 1  I have seen this movie and I did not care for ...
# 2  In Los Angeles, the alcoholic and lazy Hank Ch...
# 3  This film is bundled along with "Gli fumavano ...
# 4  I only comment on really very good films and o...
#
#                                   Reviews (filtered)
# 0  alan rickman emma thompson give good performan...
# 1  i have seen this movie and i did not care for ...
# 2  in los angeles the alcoholic and lazy hank chi...
# 3  this film is bundled along with gli fumavano l...
# 4  i only comment on really very good films and o...

# %%
# wordfreq = {}
# for token in reviews['Reviews']:
#         if token not in wordfreq.keys():
#             wordfreq[token] = 1
#         else:
#             wordfreq[token] += 1

# %%
reviews_np = reviews['Reviews (filtered)'].to_numpy()
reviews_np
# Out:
# array(['alan rickman emma thompson give good performances with southern new orleans accents in this detective flick it s worth seeing for their scenes and rickman s scene with hal holbrook these three actors mannage to entertain us no matter what the movie it seems the plot for the movie shows potential but one gets the impression in watching the film that it was not pulled off as well as it could have been the fact that it is cluttered by a rather uninteresting subplot and mostly uninteresting kidnappers really muddles things the movie is worth a view if for nothing more than entertaining performances by rickman thompson and holbrook ',
#        'i have seen this movie and i did not care for this movie anyhow i would not think about going to paris because i do not like this country and its national capital i do not like to learn french anyhow because i do not understand their language why would i go to france when i rather go to germany or the united kingdom germany and the united kingdom are the nations i tolerate apparently the olsen twins do not understand the french language just like me therefore i will not bother the france trip no matter what i might as well stick to the united kingdom and meet single women and play video games if there is a video arcade that is all ',
#        'in los angeles the alcoholic and lazy hank chinaski matt dillon performs a wide range of non qualified functions just to get enough money to drink and gamble in horse races his primary and only objective is writing and having sexy with dirty women factotum is an uninteresting pointless and extremely boring movie about an irresponsible drunken vagrant that works a couple of days or weeks just to get enough money to buy spirits and gamble being immediately fired due to his reckless behavior in accordance with imdb this character would be the fictional alter ego of the author charles bukowski and based on this story i will certainly never read any of his novels honestly if the viewer likes this theme of alcoholic couples better off watching the touching and heartbreaking hector babenco s ironweed or marco ferreri s storie di ordinaria follia that is based on the life of the same writer my vote is four title brazil factotum sem destino factotum without destiny ',
#        ...,
#        'when something can be anything you want it to be or mean it s bound to register with someone as being rather special but just as the shape of a cloud in the sky may appear to one of us or remind us of a battleship and to another of his aunt s rear and yet to another absolutely nothing other than a cloud this does not make this cloud meaningful except for the viewers interpretation anyone who might find throwing a stuffed giraffe out of a window brilliant or worthwhile for that matter without relating it in some context is possibly merely trying to impress us with his or her intellectuality submitting to this movie as the dreams of a madman does quite nicely especially since there is no standard or expectation for what said dreams would be like and even if we were mad ourselves this would hardly give us sane reference points for comparison a love affair with this movie entails the same risk as seriously interpreting nostradamus whatever real meaning was being conveyed at the time might be buried in the private jokes musings or provincial minutiae of its day and to a select few radical intellectuals at that i did spot a bit of an agenda even with my limited capacity though the movie is definitely anti fascist and to some extent anti italian i noted that although the years were years of great public works and urban renewal in italy any indication of this seemed avoided furthermore avant guarde academic spinners take note of this for your next class the very short cropped haired man with the mustache in the party segment near the end is a caricature of victor emmanuel iii and his tall female companion none other than queen helen formerly princess of montenegro without an understanding of potential historical relevance even the apparent irrelevance is beyond the competence of academic or other intellectual poseurs who would bask in irrelevance to impress us i gladly add my own paint buckets to the defacement of this cinematic joke but in an adaptation of the famous mot by the little boy the movie really has no face to deface paint would help it burn though ',
#        'i had heard good things about states of grace and came in with an open mind i thought that god s army was okay and i thought that maybe dutcher had improved and matured as a filmmaker the film began with some shaky acting and i thought well maybe it will get better unfortunately it never did the picture starts out by introducing two elders mormon missionaries and it seems that the audience will get to know them and grow to care about them instead the story degenerates into a highly improbable series of unfortunate events highlighting blatant disobedience by the missionaries something that undeniably exists but rarely on the level that dutcher portrays and it becomes almost laughable dutcher s only success in this movie is his successful alienation of his target audience by unrealistically and inaccurately portraying the lives of mormon missionaries dutcher accomplishes nothing more than angering his predominantly mormon audience the film in no way reflects reality missions are nothing like what dutcher shows having served a mormon mission myself i can attest to this fact and gang life in california certainly contains much more explicit language than the occasional mild vulgarity the conclusion which i m assuming was supposed to touch the audience and inspire them to believe that forgiveness is available to all was both unbelievable c mon the entire mission gathers to see this elder sent home and the mom and the girl are standing right next to each other and cheesy next time dutcher try making a movie that someone can identify with ',
#        'well this movie actually did have one redeeming quality it made up the funniest season one episode of mst k i wish rhino had released this one instead of the crawling hand '],
#       dtype=object)

# %%
wordfreq = {}
for sentence in reviews_np:
    for token in sentence:
        if token not in wordfreq.keys():
            wordfreq[token] = 1
        else:
            wordfreq[token] += 1

# %%
wordfreq
# Out:
# {'a': 992958,
#  'l': 542417,
#  'n': 818262,
#  ' ': 2889648,
#  'r': 686940,
#  'i': 950811,
#  'c': 347422,
#  'k': 113507,
#  'm': 338253,
#  'e': 1488823,
#  't': 1186916,
#  'h': 686524,
#  'o': 950543,
#  'p': 217100,
#  's': 838677,
#  'g': 262769,
#  'v': 160789,
#  'd': 441800,
#  'f': 269641,
#  'w': 251278,
#  'u': 339866,
#  'b': 205497,
#  'y': 257937,
#  'j': 28143,
#  'z': 9970,
#  'q': 9375,
#  'x': 20530}

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
CV = CountVectorizer(input="content", lowercase=False)

# %%
CV

# %%
vocab = CV.fit_transform(reviews_np)

# %%
vocab

# %%
CV.get_feature_names()

# %%
vocab.toarray()

# %%
from sklearn.linear_model import LogisticRegression

# %%
test_neg_path = "../train_neg.txt"
test_pos_path = "../train_pos.txt"
reviews1 = pd.read_table(test_neg_path, sep="\n", header=None, names=['Reviews'])
reviews1['Encoding'] = 0
reviews1.head()


# df = pd.concat('')

# %%
reviews2 = pd.read_table(test_pos_path, sep="\n", header=None, names=['Reviews'])
reviews2['Encoding'] = 1
reviews2.head()

# %%
df = pd.concat([reviews1, reviews2])

# %%
df

# %%
df['reviews_cleaned'] = \
    df['Reviews'].apply(tokenize_words, args=(stop_words, punctuation))

# %%
df

# %%
CV = CountVectorizer(input="content", lowercase=False)

# %%
CV

# %%
vocab = CV.fit_transform(df['reviews_cleaned'])

# %%
vocab

# %%
CV.get_feature_names()

# %%
vocab.toarray()

# %%
df['matrixdf'] = list(vocab.toarray())

# %%
df.iloc[0,3]

# %%
LogisticRegression

# %%
X_train = vocab.toarray()
y_train = df['Encoding']

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)

# %%
model.score(X_train, y_train)

# %%
test_neg_path = "../test_neg.txt"
test_pos_path = "../test_pos.txt"

test_neg_df = pd.read_table(test_neg_path, sep="\n", header=None, names=['Reviews'])
test_pos_df = pd.read_table(test_pos_path, sep="\n", header=None, names=['Reviews'])

test_neg_df['Encoding'] = 0
test_pos_df['Encoding'] = 1

test_df = pd.concat([test_neg_df, test_pos_df])

test_df['Reviews (Cleaned)'] = test_df['Reviews'].apply(tokenize_words, args=(stop_words, punctuation))

test_df

# %%
X_test = CV.transform(test_df['Reviews (Cleaned)']).toarray()

# %%
X_test

# %%
# y_test = test_df['Encoding']
# model.score(X_test, y_test)

# %%
X

# %%
prediction = model.predict(X_test[12444].reshape(1,-1))
print(f"Review: {test_df.iloc[12444,0]}")
print(f"Actual Classifier: {test_df.iloc[12444, 1]}")
print(f"Prediction: {prediction}")

# %%
CV.

# %%
stop_words = set(stopwords.words("english"))
punctuation = string.punctuation
from functools import reduce


def tokenize_words(text, stopwords, punctuation):
    text = text.lower() 
    text = text.replace("<br />", " ")
    text = re.sub(r"[^a-z ]", " ", text)
    text = re.sub(r" +", " ", text)
    tokens = word_tokenize(text)
    filtered = []
    for w in tokens:
        if w not in stopwords and w not in punctuation:
            filtered.append(w)
    text = reduce((lambda x,y: x + " " + y), filtered)
    return text

# %%
import io 
import re
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
#word_tokenize accepts a string as an input, not a file. 
stop_words = set(stopwords.words('english')) 
stop_words = [re.sub(r"[^a-z ]", "", w) for w in stop_words]


test_neg_path = "../train_neg.txt"
test_pos_path = "../train_pos.txt"

test_neg_df = pd.read_table(test_neg_path, sep="\n", header=None, names=['Reviews'])
test_pos_df = pd.read_table(test_pos_path, sep="\n", header=None, names=['Reviews'])

test_neg_df['Encoding'] = 0
test_pos_df['Encoding'] = 1

test_df = pd.concat([test_neg_df, test_pos_df])

test_df['Reviews (Cleaned)'] = test_df['Reviews'].apply(tokenize_words, args=(stop_words, punctuation))

test_df
# Out:
#                                                  Reviews  Encoding  \
# 0      Working with one of the best Shakespeare sourc...         0
# 1      Well...tremors I, the original started off in ...         0
# 2      Ouch! This one was a bit painful to sit throug...         0
# 3      I've seen some crappy movies in my life, but t...         0
# 4      Carriers follows the exploits of two guys and ...         0
# ...                                                  ...       ...
# 12495  My comments may be a bit of a spoiler, for wha...         1
# 12496  The "saucy" misadventures of four au pairs who...         1
# 12497  Oh, those Italians! Assuming that movies about...         1
# 12498  Eight academy nominations? It's beyond belief....         1
# 12499  Not that I dislike childrens movies, but this ...         1
#
#                                        Reviews (Cleaned)
# 0      working one best shakespeare sources film mana...
# 1      well tremors original started found movie quit...
# 2      ouch one bit painful sit cute amusing premise ...
# 3      seen crappy movies life one must among worst d...
# 4      carriers follows exploits two guys two gals st...
# ...                                                  ...
# 12495  comments may bit spoiler worth stop care enoug...
# 12496  saucy misadventures four au pairs arrive londo...
# 12497  oh italians assuming movies aristocrats weird ...
# 12498  eight academy nominations beyond belief think ...
# 12499  dislike childrens movies tearjerker redeeming ...
#
# [25000 rows x 3 columns]

# %%
wordfreq = {}
for sentence in test_df['Reviews (Cleaned)']:
    tokens = word_tokenize(sentence)
    for token in tokens:
        if token not in wordfreq.keys():
            wordfreq[token] = 1
        else:
            wordfreq[token] += 1

# %%
wordfreq
# Out:
# {'working': 662,
#  'one': 26276,
#  'best': 4192,
#  'shakespeare': 224,
#  'sources': 70,
#  'film': 38442,
#  'manages': 492,
#  'creditable': 10,
#  'source': 194,
#  'whilst': 276,
#  'still': 4566,
#  'appealing': 192,
#  'wider': 26,
#  'audience': 2356,
#  'branagh': 134,
#  'steals': 132,
#  'fishburne': 32,
#  'nose': 196,
#  'talented': 584,
#  'cast': 3392,
#  'good': 14846,
#  'form': 626,
#  'well': 8514,
#  'tremors': 64,
#  'original': 3968,
#  'started': 1090,
#  'found': 2534,
#  'movie': 49938,
#  'quite': 3192,
#  'enjoyable': 538,
#  'watch': 7100,
#  'however': 3482,
#  'proceeded': 32,
#  'make': 9444,
#  'ii': 408,
#  'iii': 152,
#  'trust': 298,
#  'movies': 8162,
#  'going': 4638,
#  'downhill': 158,
#  'right': 3250,
#  'finished': 336,
#  'first': 8614,
#  'mean': 2234,
#  'ass': 326,
#  'blasters': 4,
#  'god': 1532,
#  'capable': 230,
#  'answering': 36,
#  'question': 716,
#  'gods': 68,
#  'name': 1842,
#  'would': 14072,
#  'create': 592,
#  'another': 4508,
#  'dumpster': 14,
#  'dives': 24,
#  'iv': 76,
#  'considered': 446,
#  'bad': 14802,
#  'fact': 3678,
#  'even': 15382,
#  'epitome': 28,
#  'lives': 998,
#  'attempted': 158,
#  'sit': 898,
#  'though': 4182,
#  'noticed': 250,
#  'eyes': 1152,
#  'bleed': 84,
#  'hoped': 190,
#  'profusely': 8,
#  'little': 6192,
#  'girl': 2928,
#  'ring': 234,
#  'crawl': 54,
#  'tv': 2764,
#  'kill': 1454,
#  'really': 12526,
#  'think': 7286,
#  'dressing': 78,
#  'people': 9614,
#  'stared': 24,
#  'wild': 344,
#  'west': 434,
#  'exact': 224,
#  'occurrences': 24,
#  'better': 6716,
#  'honestly': 656,
#  'never': 6518,
#  'suggest': 388,
#  'buying': 190,
#  'cheaper': 58,
#  'ways': 616,
#  'find': 3720,
#  'things': 3678,
#  'burn': 170,
#  'ouch': 28,
#  'bit': 2596,
#  'painful': 616,
#  'cute': 556,
#  'amusing': 524,
#  'premise': 970,
#  'goes': 2512,
#  'hell': 1320,
#  'matthew': 114,
#  'modine': 34,
#  'almost': 3148,
#  'always': 2302,
#  'pedestrian': 84,
#  'annoying': 1590,
#  'disappoint': 60,
#  'deborah': 46,
#  'kara': 18,
#  'unger': 8,
#  'john': 1716,
#  'neville': 6,
#  'turned': 1036,
#  'surprisingly': 308,
#  'decent': 1630,
#  'performances': 1168,
#  'alan': 262,
#  'bates': 38,
#  'jennifer': 268,
#  'tilly': 42,
#  'among': 590,
#  'others': 1332,
#  'played': 2034,
#  'way': 7978,
#  'top': 1570,
#  'know': 6668,
#  'parts': 1092,
#  'written': 1658,
#  'hard': 2748,
#  'blame': 438,
#  'actors': 4882,
#  'script': 4150,
#  'director': 4816,
#  'schlock': 98,
#  'outrageous': 118,
#  'characters': 7200,
#  'ok': 1432,
#  'got': 4054,
#  'ta': 174,
#  'material': 874,
#  'work': 4056,
#  'run': 1334,
#  'away': 2940,
#  'screaming': 424,
#  'possible': 1108,
#  'seen': 6532,
#  'crappy': 398,
#  'life': 4858,
#  'must': 3044,
#  'worst': 4960,
#  'definately': 14,
#  'bottom': 582,
#  'imo': 48,
#  'follow': 678,
#  'two': 6346,
#  'couples': 92,
#  'dodds': 2,
#  'billy': 326,
#  'bob': 236,
#  'thornton': 42,
#  'lonnie': 12,
#  'earl': 66,
#  'natasha': 38,
#  'richardson': 38,
#  'darlene': 8,
#  'kirkendalls': 2,
#  'patrick': 148,
#  'swayze': 32,
#  'roy': 150,
#  'charlize': 12,
#  'theron': 14,
#  'candy': 252,
#  'car': 1468,
#  'roadtrip': 2,
#  'reno': 48,
#  'apparently': 1280,
#  'happy': 732,
#  'sex': 2092,
#  'cheats': 30,
#  'wife': 1888,
#  'despirately': 2,
#  'trying': 2972,
#  'baby': 686,
#  'meanwhile': 236,
#  'sure': 2866,
#  'sperm': 24,
#  'getting': 1826,
#  'checked': 96,
#  'doctor': 656,
#  'read': 2164,
#  'back': 4848,
#  'dvd': 2042,
#  'girlfriend': 706,
#  'blurted': 6,
#  'minutes': 4252,
#  'oh': 2172,
#  'yeah': 658,
#  'gon': 320,
#  'na': 576,
#  'end': 5910,
#  'pregnant': 226,
#  'husband': 908,
#  'spot': 330,
#  'soooo': 40,
#  'predictable': 1256,
#  'boring': 2958,
#  'meaningless': 170,
#  'offensive': 320,
#  'terrible': 2782,
#  'example': 1490,
#  'much': 10156,
#  'stinks': 160,
#  'set': 2354,
#  'big': 3324,
#  'towards': 586,
#  'nevada': 28,
#  'stopped': 276,
#  'police': 1036,
#  'officers': 96,
#  'stop': 1236,
#  'sign': 338,
#  'guys': 1528,
#  'finally': 1432,
#  'bribe': 12,
#  'case': 1614,
#  'beer': 138,
#  'scene': 5632,
#  'pointless': 930,
#  'important': 742,
#  'relevant': 130,
#  'takes': 1900,
#  'talk': 934,
#  'without': 3192,
#  'ever': 6528,
#  'somewhere': 616,
#  'puke': 44,
#  'thinking': 1440,
#  'ending': 2360,
#  'problems': 848,
#  'father': 1452,
#  'child': 1206,
#  'many': 5818,
#  'times': 2812,
#  'happen': 1146,
#  'try': 2102,
#  'something': 5884,
#  'new': 3708,
#  'cheated': 136,
#  'ultimately': 504,
#  'forgives': 14,
#  'friend': 1222,
#  'affair': 316,
#  'live': 1236,
#  'happily': 128,
#  'yuck': 44,
#  'couple': 1806,
#  'shots': 1118,
#  'grand': 222,
#  'canyon': 62,
#  'keep': 1540,
#  'camera': 2122,
#  'expect': 1188,
#  'although': 2074,
#  'tries': 1580,
#  'writers': 836,
#  'shame': 796,
#  'carriers': 18,
#  'follows': 388,
#  'exploits': 46,
#  'gals': 24,
#  'stolen': 208,
#  'mercedes': 14,
#  'words': 900,
#  'road': 408,
#  'warrior': 148,
#  'hood': 192,
#  'hightailing': 2,
#  'highway': 60,
#  'beach': 198,
#  'surfboards': 6,
#  'strapped': 40,
#  'brian': 246,
#  'chris': 404,
#  'pine': 32,
#  'star': 1870,
#  'trek': 164,
#  'driving': 316,
#  'bobby': 122,
#  'piper': 36,
#  'perabo': 14,
#  'coyote': 34,
#  'ugly': 530,
#  'shotgun': 76,
#  'younger': 402,
#  'brother': 922,
#  'danny': 184,
#  'lou': 160,
#  'taylor': 256,
#  'pucci': 4,
#  'fanboys': 14,
#  'exactly': 1040,
#  'kate': 288,
#  'emily': 84,
#  'vancamp': 2,
#  'occupy': 18,
#  'backseat': 10,
#  'quartet': 22,
#  'twentysomething': 4,
#  'living': 902,
#  'nightmare': 348,
#  'viral': 6,
#  'pandemic': 4,
#  'co': 596,
#  'directors': 670,
#  'scenarists': 6,
#  'alex': 258,
#  'pastor': 18,
#  'david': 746,
#  'tell': 1918,
#  'us': 3258,
#  'absolutely': 1684,
#  'nothing': 5980,
#  'devastated': 18,
#  'america': 610,
#  'naturally': 274,
#  'lack': 1396,
#  'exposition': 112,
#  'shaves': 10,
#  'least': 4022,
#  'fifteen': 164,
#  'slowed': 22,
#  'cynical': 118,
#  'melodrama': 132,
#  'humans': 374,
#  'degenerate': 30,
#  'crisis': 116,
#  'become': 1256,
#  'enemies': 82,
#  'lethal': 52,
#  'virus': 178,
#  'gives': 1092,
#  'shingles': 2,
#  'die': 934,
#  'everybody': 366,
#  'runs': 496,
#  'around': 3886,
#  'wearing': 400,
#  'white': 1452,
#  'masks': 68,
#  'mouth': 428,
#  'thin': 480,
#  'rubber': 146,
#  'band': 490,
#  'initially': 134,
#  'foursome': 10,
#  'encounters': 128,
#  'desperate': 340,
#  'frank': 286,
#  'christopher': 382,
#  'meloni': 2,
#  'runaway': 42,
#  'bride': 122,
#  'daughter': 1132,
#  'jodie': 40,
#  'kiernan': 4,
#  'shipka': 2,
#  'land': 338,
#  'lost': 1490,
#  'blocking': 22,
#  'suv': 34,
#  'swerves': 2,
#  'waylay': 2,
#  'process': 280,
#  'oil': 130,
#  'pan': 102,
#  'ruptures': 2,
#  'wind': 224,
#  'foot': 262,
#  'reluctantly': 38,
#  'hitch': 36,
#  'ride': 276,
#  'seal': 36,
#  'rear': 62,
#  'wears': 172,
#  'mask': 224,
#  'speckled': 2,
#  'blood': 1464,
#  'heard': 1122,
#  'doctors': 90,
#  'curing': 10,
#  'ailing': 12,
#  'hospital': 384,
#  'head': 1796,
#  'sadly': 728,
#  'somebody': 424,
#  'lied': 28,
#  'physician': 20,
#  'giving': 862,
#  'last': 2780,
#  'kids': 1978,
#  'kool': 10,
#  'aid': 98,
#  'put': 2526,
#  'misery': 104,
#  'cure': 118,
#  'improve': 120,
#  'condition': 126,
#  'else': 2400,
#  'town': 1080,
#  'dead': 2202,
#  'success': 438,
#  'get': 10080,
#  'dial': 52,
#  'tone': 432,
#  'every': 4050,
#  'phone': 394,
#  'realizes': 120,
#  'hope': 1344,
#  'lets': 354,
#  'heroic': 84,
#  'appropriate': 166,
#  'take': 3602,
#  'indeed': 602,
#  'qualifies': 36,
#  'relentlessly': 56,
#  'depressing': 246,
#  'effects': 2696,
#  'four': 860,
#  'sympathetic': 170,
#  'homicidal': 44,
#  'murderers': 38,
#  'protect': 132,
#  'reach': 230,
#  'country': 764,
#  'club': 444,
#  'frolic': 8,
#  'golf': 56,
#  'course': 2296,
#  'show': 5724,
#  'suits': 100,
#  'pump': 26,
#  'action': 3132,
#  'shotguns': 12,
#  'incredibly': 736,
#  'protagonists': 120,
#  'manage': 322,
#  'escape': 444,
#  'shot': 2252,
#  'scare': 278,
#  'falls': 962,
#  'water': 522,
#  'floating': 74,
#  'corpse': 164,
#  'eventually': 654,
#  'discover': 212,
#  'infected': 106,
#  'later': 1752,
#  'gas': 204,
#  'blocks': 16,
#  'like': 22482,
#  'outset': 40,
#  'pair': 210,
#  'older': 526,
#  'christian': 520,
#  'women': 1918,
#  'lies': 298,
#  'give': 3646,
#  'birth': 152,
#  'needs': 798,
#  'help': 1810,
#  'throws': 206,
#  'caution': 36,
#  'blasts': 14,
#  'ladies': 252,
#  'automatic': 64,
#  'pistol': 42,
#  'refuse': 70,
#  'catches': 102,
#  'slug': 58,
#  'leg': 132,
#  'passenger': 42,
#  'kills': 654,
#  'pizza': 48,
#  'either': 2366,
#  'laugh': 1576,
#  'humor': 1156,
#  'virtually': 264,
#  'non': 1060,
#  'existent': 286,
#  'minute': 966,
#  'heroes': 282,
#  'villains': 264,
#  'care': 1678,
#  'plight': 62,
#  'makes': 3628,
#  'impression': 446,
#  'fun': 2014,
#  'loving': 180,
#  'energetic': 26,
#  'performance': 1936,
#  'reason': 3070,
#  'hang': 154,
#  'hokum': 28,
#  'known': 910,
#  'actress': 1176,
#  'relegated': 20,
#  'inconsequential': 36,
#  'role': 2444,
#  'tragic': 174,
#  'mistake': 558,
#  'showing': 696,
#  'compassion': 44,
#  'dying': 326,
#  'pays': 78,
#  'awful': 3114,
#  'price': 240,
#  'testament': 52,
#  'change': 806,
#  'character': 7016,
#  'point': 3692,
#  'putting': 378,
#  'essentially': 274,
#  'ability': 474,
#  'pull': 350,
#  'eighty': 34,
#  'go': 5438,
#  'lucky': 206,
#  'guy': 3930,
#  'heartless': 30,
#  'spanish': 268,
#  'brothers': 404,
#  'let': 2774,
#  'momentum': 46,
#  'flag': 50,
#  'since': 2776,
#  'relief': 240,
#  'sight': 324,
#  'sinks': 56,
#  'predictability': 38,
#  'irr': 4,
#  'versible': 4,
#  'cinematographer': 86,
#  'beno': 2,
#  'debie': 4,
#  'fantastic': 288,
#  'job': 1614,
#  'widescreen': 42,
#  'lensing': 4,
#  'unsavory': 16,
#  'trip': 420,
#  'becomes': 1302,
#  'look': 4494,
#  'dynamic': 90,
#  'aside': 510,
#  'closure': 34,
#  'sense': 2612,
#  'word': 1112,
#  'suffers': 236,
#  'horribly': 344,
#  'german': 422,
#  'shepherd': 78,
#  'attacks': 182,
#  'conjures': 6,
#  'suspense': 726,
#  'could': 9372,
#  'improved': 128,
#  'unfortunately': 1862,
#  'tension': 546,
#  'fade': 74,
#  'happens': 1278,
#  'anybody': 366,
#  'looking': 2860,
#  'forward': 742,
#  'seeing': 1976,
#  'long': 3522,
#  'time': 12422,
#  'return': 510,
#  'paradise': 52,
#  'gritty': 84,
#  'disappointed': 1138,
#  'realistic': 466,
#  'thing': 5732,
#  'unpredictable': 46,
#  'partly': 108,
#  'maybe': 2808,
#  'expecting': 622,
#  'positive': 658,
#  'side': 1114,
#  'danes': 66,
#  'beckinsale': 24,
#  'pullman': 30,
#  'roles': 840,
#  'see': 10904,
#  'anything': 3748,
#  'done': 3020,
#  'emphasis': 84,
#  'prison': 434,
#  'conditions': 64,
#  'sheer': 256,
#  'horror': 4302,
#  'cheery': 16,
#  'also': 7216,
#  'predicted': 56,
#  'happened': 1184,
#  'effect': 612,
#  'cause': 584,
#  'generally': 506,
#  'real': 4340,
#  'world': 2810,
#  'hollywood': 1700,
#  'remakes': 96,
#  'required': 214,
#  'haunting': 106,
#  'given': 1956,
#  'computer': 590,
#  'treatment': 222,
#  'courtesy': 38,
#  'st': 374,
#  'class': 820,
#  'turner': 100,
#  'showed': 432,
#  'promise': 274,
#  'jan': 60,
#  'de': 570,
#  'bont': 16,
#  'speed': 242,
#  'produced': 550,
#  'string': 156,
#  'budget': 2360,
#  'garbage': 776,
#  'twister': 24,
#  'actor': 2370,
#  'superfluous': 56,
#  'type': 1094,
#  'seem': 2294,
#  'realize': 660,
#  'liam': 44,
#  'neeson': 32,
#  'cathrine': 4,
#  'zeta': 66,
#  'jones': 442,
#  'act': 1458,
#  'wish': 916,
#  'anywhere': 358,
#  'lili': 20,
#  'attempt': 1470,
#  'add': 886,
#  'proceedings': 102,
#  'whatever': 920,
#  'might': 3316,
#  'unknown': 256,
#  'feels': 826,
#  'half': 2684,
#  'missing': 630,
#  'events': 718,
#  'ghosts': 214,
#  'rhyme': 58,
#  'story': 10420,
#  'ends': 1018,
#  'unsatisfying': 76,
#  'event': 334,
#  'meant': 682,
#  'wrap': 80,
#  'previous': 626,
#  'inanity': 12,
#  'screen': 2376,
#  'service': 190,
#  'instead': 2958,
#  'sake': 340,
#  'picture': 1302,
#  'intentions': 212,
#  'bacon': 88,
#  'scientist': 456,
#  'test': 238,
#  'theory': 220,
#  'invisibility': 34,
#  'shue': 28,
#  'usual': 852,
#  'apart': 648,
#  'typical': 686,
#  'thriller': 756,
#  'filmed': 740,
#  'soundstage': 20,
#  'special': 2204,
#  'galore': 34,
#  'minus': 108,
#  'kind': 3078,
#  'humour': 360,
#  'wit': 200,
#  'soul': 366,
#  'waste': 2718,
#  'watching': 5280,
#  'audiocassette': 2,
#  'tape': 200,
#  'delancie': 2,
#  'invisible': 202,
#  'man': 5034,
#  'starring': 398,
#  'leonard': 144,
#  'nimoy': 22,
#  'hg': 14,
#  'wells': 80,
#  'served': 174,
#  'unlike': 390,
#  'mess': 1082,
#  'chose': 234,
#  'score': 820,
#  'imdb': 880,
#  'lot': 3784,
#  'poor': 2962,
#  'taste': 460,
#  'someone': 2982,
#  'fixing': 26,
#  'disappointment': 636,
#  'stupid': 2856,
#  'far': 3240,
#  'fetched': 108,
#  'title': 1656,
#  'summary': 222,
#  'plot': 8310,
#  'felt': 1668,
#  'cool': 980,
#  'snakes': 124,
#  'plane': 372,
#  'crazy': 684,
#  'start': 1912,
#  'biting': 64,
#  'stuff': 1346,
#  'unoriginal': 148,
#  'cgi': 482,
#  'cut': 1260,
#  'corners': 32,
#  'mind': 1980,
#  'recommend': 1338,
#  'anyone': 2836,
#  'acting': 8112,
#  'unbelievable': 678,
#  'stereo': 38,
#  'types': 262,
#  'sum': 208,
#  'stay': 944,
#  'deceives': 6,
#  'line': 2036,
#  'laughable': 768,
#  'cringe': 160,
#  'zombie': 1020,
#  'nation': 128,
#  'implies': 54,
#  'hoard': 2,
#  'zombies': 816,
#  'six': 368,
#  'total': 874,
#  'categorised': 6,
#  'due': 842,
#  'introduction': 156,
#  'cheesy': 812,
#  'music': 2636,
#  'attack': 536,
#  'actually': 4900,
#  'human': 1190,
#  'beings': 100,
#  'difference': 362,
#  'looks': 3056,
#  'la': 510,
#  'roux': 2,
#  'video': 2086,
#  'chance': 896,
#  'buy': 744,
#  'copy': 518,
#  'brain': 696,
#  'bought': 476,
#  'ignorance': 92,
#  'thought': 3596,
#  'peter': 632,
#  'jackson': 250,
#  'stood': 94,
#  'dire': 208,
#  'promotes': 14,
#  'stare': 80,
#  'middle': 1026,
#  'distance': 118,
#  'taking': 928,
#  'lessons': 132,
#  'joey': 68,
#  'tribbiani': 2,
#  'stick': 628,
#  'plus': 672,
#  'confused': 436,
#  'sat': 434,
#  'dream': 510,
#  'frustration': 94,
#  'sets': 770,
#  'within': 754,
#  'avoid': 1286,
#  'plague': 162,
#  'young': 2634,
#  'carry': 364,
#  'limb': 14,
#  'regeneration': 8,
#  'overbearing': 52,
#  'mother': 1258,
#  'convinced': 228,
#  'murdered': 304,
#  'monitoring': 8,
#  'progress': 82,
#  'evil': 1576,
#  'purposes': 84,
#  'uses': 442,
#  'reptilian': 18,
#  'dna': 36,
#  'extracts': 16,
#  'large': 526,
#  'creature': 444,
#  'arm': 202,
#  'conveniently': 90,
#  'ripped': 224,
#  'injects': 26,
#  'formula': 250,
#  'grows': 108,
#  'murderous': 90,
#  'admittedly': 158,
#  'severed': 98,
#  'ties': 90,
#  'pretty': 4230,
#  'grotesque': 78,
#  'rest': 2044,
#  'behaving': 48,
#  'snake': 152,
#  'deal': 602,
#  'mediocre': 580,
#  'climax': 420,
#  'silly': 1202,
#  'inept': 290,
#  'incoherent': 262,
#  'supernatural': 200,
#  'college': 598,
#  'student': 436,
#  'cassie': 76,
#  'melissa': 68,
#  'sagemiller': 22,
#  'constant': 290,
#  'victim': 448,
#  'hallucinations': 46,
#  'nightmares': 110,
#  'accident': 320,
#  'claims': 246,
#  'boyfriend': 454,
#  'sean': 294,
#  'casey': 30,
#  'affleck': 102,
#  'begin': 760,
#  'importance': 82,
#  'sort': 1680,
#  'actual': 876,
#  'entertainment': 804,
#  'value': 634,
#  'particular': 584,
#  'unconvincing': 324,
#  'promote': 88,
#  'joke': 968,
#  'scares': 228,
#  'songs': 756,
#  'earth': 982,
#  'project': 606,
#  'green': 382,
#  'light': 764,
#  'writer': 1262,
#  'steve': 432,
#  'carpenter': 134,
#  'discernible': 56,
#  'vision': 238,
#  'talent': 1026,
#  'conclusion': 508,
#  'whole': 3536,
#  'alleged': 84,
#  'killer': 1830,
#  'watched': 2284,
#  'pure': 488,
#  'tedium': 68,
#  'saw': 2950,
#  'box': 730,
#  'cover': 690,
#  'stretched': 116,
#  'photography': 328,
#  'scwarz': 2,
#  'ft': 34,
#  'feet': 252,
#  'tall': 136,
#  'fault': 278,
#  'rating': 1082,
#  'night': 2166,
#  'tucson': 4,
#  'second': 1906,
#  'deck': 34,
#  'cigar': 32,
#  'roll': 310,
#  'hill': 280,
#  'needed': 784,
#  'diversion': 20,
#  'totally': 1534,
#  'enjoyed': 734,
#  'bottle': 88,
#  'merlot': 4,
#  'admit': 638,
#  'truly': 1452,
#  'feel': 2708,
#  'close': 1250,
#  'hitting': 148,
#  'mark': 572,
#  'frantic': 40,
#  'clueless': 102,
#  'comes': 2448,
#  'slow': 1314,
#  'chase': 490,
#  'wow': 538,
#  'safer': 10,
#  'warm': 122,
#  'thankful': 42,
#  'conserved': 2,
#  'gasoline': 22,
#  'less': 2134,
#  'production': 2006,
#  'summer': 308,
#  'months': 234,
#  'anywho': 4,
#  'direction': 1496,
#  'uninspired': 216,
#  'fight': 1134,
#  'sequences': 690,
#  'choreographed': 92,
#  'tightened': 10,
#  'sound': 1484,
#  'delivery': 186,
#  'hit': 936,
#  'kept': 860,
#  'locals': 72,
#  'village': 216,
#  'rather': 2788,
#  'cue': 110,
#  'happening': 424,
#  'lens': 42,
#  'deer': 58,
#  'lights': 144,
#  'smile': 216,
#  'smiling': 52,
#  'columbu': 4,
#  'bet': 264,
#  'heart': 738,
#  'caring': 152,
#  'spirit': 416,
#  'countrymen': 6,
#  'baretta': 8,
#  'island': 660,
#  'lethargic': 38,
#  'x': 352,
#  'hates': 100,
#  'love': 4304,
#  'funny': 4674,
#  'discriminating': 10,
#  'franco': 124,
#  'adding': 158,
#  'addendum': 4,
#  'killing': 874,
#  'hours': 1148,
#  'straight': 1006,
#  'b': 1556,
#  'library': 118,
#  'collection': 278,
#  'check': 782,
#  'sweat': 60,
#  'robert': 764,
#  'z': 138,
#  'dar': 8,
#  'tango': 30,
#  'cash': 300,
#  'bomb': 326,
#  'cop': 734,
#  'discovery': 88,
#  'lame': 1304,
#  'crutches': 10,
#  'ran': 232,
#  'money': 3280,
#  'fire': 684,
#  'credits': 808,
#  'gave': 1256,
#  'overall': 1218,
#  'waiting': 576,
#  'sequel': 1044,
#  'revenge': 592,
#  'montazuma': 2,
#  'mexican': 194,
#  'vacation': 150,
#  'gets': 3428,
#  'sick': 586,
#  'declares': 24,
#  ...}

# %%
len(wordfreq.keys())
# Out:
# 53070

# %%
import heapq
most_freq = heapq.nlargest(200, wordfreq, key=wordfreq.get)

# %%
most_freq
# Out:
# ['movie',
#  'film',
#  'one',
#  'like',
#  'even',
#  'good',
#  'bad',
#  'would',
#  'really',
#  'time',
#  'see',
#  'story',
#  'much',
#  'get',
#  'people',
#  'make',
#  'could',
#  'made',
#  'first',
#  'well',
#  'plot',
#  'movies',
#  'acting',
#  'way',
#  'think',
#  'also',
#  'characters',
#  'watch',
#  'character',
#  'better',
#  'know',
#  'seen',
#  'ever',
#  'never',
#  'two',
#  'little',
#  'films',
#  'nothing',
#  'say',
#  'end',
#  'something',
#  'many',
#  'thing',
#  'show',
#  'scene',
#  'scenes',
#  'go',
#  'great',
#  'watching',
#  'man',
#  'worst',
#  'actually',
#  'actors',
#  'life',
#  'back',
#  'director',
#  'funny',
#  'going',
#  'still',
#  'another',
#  'look',
#  'old',
#  'real',
#  'love',
#  'horror',
#  'want',
#  'minutes',
#  'pretty',
#  'best',
#  'though',
#  'script',
#  'work',
#  'got',
#  'every',
#  'seems',
#  'least',
#  'enough',
#  'original',
#  'guy',
#  'around',
#  'part',
#  'lot',
#  'anything',
#  'find',
#  'new',
#  'point',
#  'fact',
#  'things',
#  'give',
#  'makes',
#  'take',
#  'thought',
#  'whole',
#  'long',
#  'years',
#  'however',
#  'gets',
#  'cast',
#  'making',
#  'big',
#  'might',
#  'interesting',
#  'money',
#  'us',
#  'right',
#  'far',
#  'quite',
#  'without',
#  'come',
#  'almost',
#  'action',
#  'awful',
#  'kind',
#  'reason',
#  'looks',
#  'must',
#  'done',
#  'comedy',
#  'someone',
#  'trying',
#  'poor',
#  'boring',
#  'instead',
#  'saw',
#  'away',
#  'girl',
#  'probably',
#  'believe',
#  'sure',
#  'looking',
#  'stupid',
#  'anyone',
#  'times',
#  'world',
#  'maybe',
#  'rather',
#  'terrible',
#  'last',
#  'may',
#  'since',
#  'let',
#  'tv',
#  'hard',
#  'waste',
#  'woman',
#  'feel',
#  'effects',
#  'half',
#  'music',
#  'young',
#  'idea',
#  'sense',
#  'bit',
#  'book',
#  'found',
#  'series',
#  'put',
#  'goes',
#  'worse',
#  'said',
#  'comes',
#  'role',
#  'main',
#  'else',
#  'everything',
#  'yet',
#  'low',
#  'screen',
#  'supposed',
#  'actor',
#  'either',
#  'ending',
#  'budget',
#  'audience',
#  'set',
#  'family',
#  'left',
#  'completely',
#  'wrong',
#  'always',
#  'course',
#  'place',
#  'seem',
#  'watched',
#  'day',
#  'simply',
#  'shot',
#  'mean',
#  'special',
#  'dead',
#  'three',
#  'oh',
#  'house',
#  'night',
#  'read',
#  'less',
#  'high',
#  'year',
#  'camera',
#  'worth']

# %%
# wordfreq_df = pd.DataFrame(wordfreq, index=[1])

# %%
wordfreq
# Out:
# {'working': 662,
#  'one': 26276,
#  'best': 4192,
#  'shakespeare': 224,
#  'sources': 70,
#  'film': 38442,
#  'manages': 492,
#  'creditable': 10,
#  'source': 194,
#  'whilst': 276,
#  'still': 4566,
#  'appealing': 192,
#  'wider': 26,
#  'audience': 2356,
#  'branagh': 134,
#  'steals': 132,
#  'fishburne': 32,
#  'nose': 196,
#  'talented': 584,
#  'cast': 3392,
#  'good': 14846,
#  'form': 626,
#  'well': 8514,
#  'tremors': 64,
#  'original': 3968,
#  'started': 1090,
#  'found': 2534,
#  'movie': 49938,
#  'quite': 3192,
#  'enjoyable': 538,
#  'watch': 7100,
#  'however': 3482,
#  'proceeded': 32,
#  'make': 9444,
#  'ii': 408,
#  'iii': 152,
#  'trust': 298,
#  'movies': 8162,
#  'going': 4638,
#  'downhill': 158,
#  'right': 3250,
#  'finished': 336,
#  'first': 8614,
#  'mean': 2234,
#  'ass': 326,
#  'blasters': 4,
#  'god': 1532,
#  'capable': 230,
#  'answering': 36,
#  'question': 716,
#  'gods': 68,
#  'name': 1842,
#  'would': 14072,
#  'create': 592,
#  'another': 4508,
#  'dumpster': 14,
#  'dives': 24,
#  'iv': 76,
#  'considered': 446,
#  'bad': 14802,
#  'fact': 3678,
#  'even': 15382,
#  'epitome': 28,
#  'lives': 998,
#  'attempted': 158,
#  'sit': 898,
#  'though': 4182,
#  'noticed': 250,
#  'eyes': 1152,
#  'bleed': 84,
#  'hoped': 190,
#  'profusely': 8,
#  'little': 6192,
#  'girl': 2928,
#  'ring': 234,
#  'crawl': 54,
#  'tv': 2764,
#  'kill': 1454,
#  'really': 12526,
#  'think': 7286,
#  'dressing': 78,
#  'people': 9614,
#  'stared': 24,
#  'wild': 344,
#  'west': 434,
#  'exact': 224,
#  'occurrences': 24,
#  'better': 6716,
#  'honestly': 656,
#  'never': 6518,
#  'suggest': 388,
#  'buying': 190,
#  'cheaper': 58,
#  'ways': 616,
#  'find': 3720,
#  'things': 3678,
#  'burn': 170,
#  'ouch': 28,
#  'bit': 2596,
#  'painful': 616,
#  'cute': 556,
#  'amusing': 524,
#  'premise': 970,
#  'goes': 2512,
#  'hell': 1320,
#  'matthew': 114,
#  'modine': 34,
#  'almost': 3148,
#  'always': 2302,
#  'pedestrian': 84,
#  'annoying': 1590,
#  'disappoint': 60,
#  'deborah': 46,
#  'kara': 18,
#  'unger': 8,
#  'john': 1716,
#  'neville': 6,
#  'turned': 1036,
#  'surprisingly': 308,
#  'decent': 1630,
#  'performances': 1168,
#  'alan': 262,
#  'bates': 38,
#  'jennifer': 268,
#  'tilly': 42,
#  'among': 590,
#  'others': 1332,
#  'played': 2034,
#  'way': 7978,
#  'top': 1570,
#  'know': 6668,
#  'parts': 1092,
#  'written': 1658,
#  'hard': 2748,
#  'blame': 438,
#  'actors': 4882,
#  'script': 4150,
#  'director': 4816,
#  'schlock': 98,
#  'outrageous': 118,
#  'characters': 7200,
#  'ok': 1432,
#  'got': 4054,
#  'ta': 174,
#  'material': 874,
#  'work': 4056,
#  'run': 1334,
#  'away': 2940,
#  'screaming': 424,
#  'possible': 1108,
#  'seen': 6532,
#  'crappy': 398,
#  'life': 4858,
#  'must': 3044,
#  'worst': 4960,
#  'definately': 14,
#  'bottom': 582,
#  'imo': 48,
#  'follow': 678,
#  'two': 6346,
#  'couples': 92,
#  'dodds': 2,
#  'billy': 326,
#  'bob': 236,
#  'thornton': 42,
#  'lonnie': 12,
#  'earl': 66,
#  'natasha': 38,
#  'richardson': 38,
#  'darlene': 8,
#  'kirkendalls': 2,
#  'patrick': 148,
#  'swayze': 32,
#  'roy': 150,
#  'charlize': 12,
#  'theron': 14,
#  'candy': 252,
#  'car': 1468,
#  'roadtrip': 2,
#  'reno': 48,
#  'apparently': 1280,
#  'happy': 732,
#  'sex': 2092,
#  'cheats': 30,
#  'wife': 1888,
#  'despirately': 2,
#  'trying': 2972,
#  'baby': 686,
#  'meanwhile': 236,
#  'sure': 2866,
#  'sperm': 24,
#  'getting': 1826,
#  'checked': 96,
#  'doctor': 656,
#  'read': 2164,
#  'back': 4848,
#  'dvd': 2042,
#  'girlfriend': 706,
#  'blurted': 6,
#  'minutes': 4252,
#  'oh': 2172,
#  'yeah': 658,
#  'gon': 320,
#  'na': 576,
#  'end': 5910,
#  'pregnant': 226,
#  'husband': 908,
#  'spot': 330,
#  'soooo': 40,
#  'predictable': 1256,
#  'boring': 2958,
#  'meaningless': 170,
#  'offensive': 320,
#  'terrible': 2782,
#  'example': 1490,
#  'much': 10156,
#  'stinks': 160,
#  'set': 2354,
#  'big': 3324,
#  'towards': 586,
#  'nevada': 28,
#  'stopped': 276,
#  'police': 1036,
#  'officers': 96,
#  'stop': 1236,
#  'sign': 338,
#  'guys': 1528,
#  'finally': 1432,
#  'bribe': 12,
#  'case': 1614,
#  'beer': 138,
#  'scene': 5632,
#  'pointless': 930,
#  'important': 742,
#  'relevant': 130,
#  'takes': 1900,
#  'talk': 934,
#  'without': 3192,
#  'ever': 6528,
#  'somewhere': 616,
#  'puke': 44,
#  'thinking': 1440,
#  'ending': 2360,
#  'problems': 848,
#  'father': 1452,
#  'child': 1206,
#  'many': 5818,
#  'times': 2812,
#  'happen': 1146,
#  'try': 2102,
#  'something': 5884,
#  'new': 3708,
#  'cheated': 136,
#  'ultimately': 504,
#  'forgives': 14,
#  'friend': 1222,
#  'affair': 316,
#  'live': 1236,
#  'happily': 128,
#  'yuck': 44,
#  'couple': 1806,
#  'shots': 1118,
#  'grand': 222,
#  'canyon': 62,
#  'keep': 1540,
#  'camera': 2122,
#  'expect': 1188,
#  'although': 2074,
#  'tries': 1580,
#  'writers': 836,
#  'shame': 796,
#  'carriers': 18,
#  'follows': 388,
#  'exploits': 46,
#  'gals': 24,
#  'stolen': 208,
#  'mercedes': 14,
#  'words': 900,
#  'road': 408,
#  'warrior': 148,
#  'hood': 192,
#  'hightailing': 2,
#  'highway': 60,
#  'beach': 198,
#  'surfboards': 6,
#  'strapped': 40,
#  'brian': 246,
#  'chris': 404,
#  'pine': 32,
#  'star': 1870,
#  'trek': 164,
#  'driving': 316,
#  'bobby': 122,
#  'piper': 36,
#  'perabo': 14,
#  'coyote': 34,
#  'ugly': 530,
#  'shotgun': 76,
#  'younger': 402,
#  'brother': 922,
#  'danny': 184,
#  'lou': 160,
#  'taylor': 256,
#  'pucci': 4,
#  'fanboys': 14,
#  'exactly': 1040,
#  'kate': 288,
#  'emily': 84,
#  'vancamp': 2,
#  'occupy': 18,
#  'backseat': 10,
#  'quartet': 22,
#  'twentysomething': 4,
#  'living': 902,
#  'nightmare': 348,
#  'viral': 6,
#  'pandemic': 4,
#  'co': 596,
#  'directors': 670,
#  'scenarists': 6,
#  'alex': 258,
#  'pastor': 18,
#  'david': 746,
#  'tell': 1918,
#  'us': 3258,
#  'absolutely': 1684,
#  'nothing': 5980,
#  'devastated': 18,
#  'america': 610,
#  'naturally': 274,
#  'lack': 1396,
#  'exposition': 112,
#  'shaves': 10,
#  'least': 4022,
#  'fifteen': 164,
#  'slowed': 22,
#  'cynical': 118,
#  'melodrama': 132,
#  'humans': 374,
#  'degenerate': 30,
#  'crisis': 116,
#  'become': 1256,
#  'enemies': 82,
#  'lethal': 52,
#  'virus': 178,
#  'gives': 1092,
#  'shingles': 2,
#  'die': 934,
#  'everybody': 366,
#  'runs': 496,
#  'around': 3886,
#  'wearing': 400,
#  'white': 1452,
#  'masks': 68,
#  'mouth': 428,
#  'thin': 480,
#  'rubber': 146,
#  'band': 490,
#  'initially': 134,
#  'foursome': 10,
#  'encounters': 128,
#  'desperate': 340,
#  'frank': 286,
#  'christopher': 382,
#  'meloni': 2,
#  'runaway': 42,
#  'bride': 122,
#  'daughter': 1132,
#  'jodie': 40,
#  'kiernan': 4,
#  'shipka': 2,
#  'land': 338,
#  'lost': 1490,
#  'blocking': 22,
#  'suv': 34,
#  'swerves': 2,
#  'waylay': 2,
#  'process': 280,
#  'oil': 130,
#  'pan': 102,
#  'ruptures': 2,
#  'wind': 224,
#  'foot': 262,
#  'reluctantly': 38,
#  'hitch': 36,
#  'ride': 276,
#  'seal': 36,
#  'rear': 62,
#  'wears': 172,
#  'mask': 224,
#  'speckled': 2,
#  'blood': 1464,
#  'heard': 1122,
#  'doctors': 90,
#  'curing': 10,
#  'ailing': 12,
#  'hospital': 384,
#  'head': 1796,
#  'sadly': 728,
#  'somebody': 424,
#  'lied': 28,
#  'physician': 20,
#  'giving': 862,
#  'last': 2780,
#  'kids': 1978,
#  'kool': 10,
#  'aid': 98,
#  'put': 2526,
#  'misery': 104,
#  'cure': 118,
#  'improve': 120,
#  'condition': 126,
#  'else': 2400,
#  'town': 1080,
#  'dead': 2202,
#  'success': 438,
#  'get': 10080,
#  'dial': 52,
#  'tone': 432,
#  'every': 4050,
#  'phone': 394,
#  'realizes': 120,
#  'hope': 1344,
#  'lets': 354,
#  'heroic': 84,
#  'appropriate': 166,
#  'take': 3602,
#  'indeed': 602,
#  'qualifies': 36,
#  'relentlessly': 56,
#  'depressing': 246,
#  'effects': 2696,
#  'four': 860,
#  'sympathetic': 170,
#  'homicidal': 44,
#  'murderers': 38,
#  'protect': 132,
#  'reach': 230,
#  'country': 764,
#  'club': 444,
#  'frolic': 8,
#  'golf': 56,
#  'course': 2296,
#  'show': 5724,
#  'suits': 100,
#  'pump': 26,
#  'action': 3132,
#  'shotguns': 12,
#  'incredibly': 736,
#  'protagonists': 120,
#  'manage': 322,
#  'escape': 444,
#  'shot': 2252,
#  'scare': 278,
#  'falls': 962,
#  'water': 522,
#  'floating': 74,
#  'corpse': 164,
#  'eventually': 654,
#  'discover': 212,
#  'infected': 106,
#  'later': 1752,
#  'gas': 204,
#  'blocks': 16,
#  'like': 22482,
#  'outset': 40,
#  'pair': 210,
#  'older': 526,
#  'christian': 520,
#  'women': 1918,
#  'lies': 298,
#  'give': 3646,
#  'birth': 152,
#  'needs': 798,
#  'help': 1810,
#  'throws': 206,
#  'caution': 36,
#  'blasts': 14,
#  'ladies': 252,
#  'automatic': 64,
#  'pistol': 42,
#  'refuse': 70,
#  'catches': 102,
#  'slug': 58,
#  'leg': 132,
#  'passenger': 42,
#  'kills': 654,
#  'pizza': 48,
#  'either': 2366,
#  'laugh': 1576,
#  'humor': 1156,
#  'virtually': 264,
#  'non': 1060,
#  'existent': 286,
#  'minute': 966,
#  'heroes': 282,
#  'villains': 264,
#  'care': 1678,
#  'plight': 62,
#  'makes': 3628,
#  'impression': 446,
#  'fun': 2014,
#  'loving': 180,
#  'energetic': 26,
#  'performance': 1936,
#  'reason': 3070,
#  'hang': 154,
#  'hokum': 28,
#  'known': 910,
#  'actress': 1176,
#  'relegated': 20,
#  'inconsequential': 36,
#  'role': 2444,
#  'tragic': 174,
#  'mistake': 558,
#  'showing': 696,
#  'compassion': 44,
#  'dying': 326,
#  'pays': 78,
#  'awful': 3114,
#  'price': 240,
#  'testament': 52,
#  'change': 806,
#  'character': 7016,
#  'point': 3692,
#  'putting': 378,
#  'essentially': 274,
#  'ability': 474,
#  'pull': 350,
#  'eighty': 34,
#  'go': 5438,
#  'lucky': 206,
#  'guy': 3930,
#  'heartless': 30,
#  'spanish': 268,
#  'brothers': 404,
#  'let': 2774,
#  'momentum': 46,
#  'flag': 50,
#  'since': 2776,
#  'relief': 240,
#  'sight': 324,
#  'sinks': 56,
#  'predictability': 38,
#  'irr': 4,
#  'versible': 4,
#  'cinematographer': 86,
#  'beno': 2,
#  'debie': 4,
#  'fantastic': 288,
#  'job': 1614,
#  'widescreen': 42,
#  'lensing': 4,
#  'unsavory': 16,
#  'trip': 420,
#  'becomes': 1302,
#  'look': 4494,
#  'dynamic': 90,
#  'aside': 510,
#  'closure': 34,
#  'sense': 2612,
#  'word': 1112,
#  'suffers': 236,
#  'horribly': 344,
#  'german': 422,
#  'shepherd': 78,
#  'attacks': 182,
#  'conjures': 6,
#  'suspense': 726,
#  'could': 9372,
#  'improved': 128,
#  'unfortunately': 1862,
#  'tension': 546,
#  'fade': 74,
#  'happens': 1278,
#  'anybody': 366,
#  'looking': 2860,
#  'forward': 742,
#  'seeing': 1976,
#  'long': 3522,
#  'time': 12422,
#  'return': 510,
#  'paradise': 52,
#  'gritty': 84,
#  'disappointed': 1138,
#  'realistic': 466,
#  'thing': 5732,
#  'unpredictable': 46,
#  'partly': 108,
#  'maybe': 2808,
#  'expecting': 622,
#  'positive': 658,
#  'side': 1114,
#  'danes': 66,
#  'beckinsale': 24,
#  'pullman': 30,
#  'roles': 840,
#  'see': 10904,
#  'anything': 3748,
#  'done': 3020,
#  'emphasis': 84,
#  'prison': 434,
#  'conditions': 64,
#  'sheer': 256,
#  'horror': 4302,
#  'cheery': 16,
#  'also': 7216,
#  'predicted': 56,
#  'happened': 1184,
#  'effect': 612,
#  'cause': 584,
#  'generally': 506,
#  'real': 4340,
#  'world': 2810,
#  'hollywood': 1700,
#  'remakes': 96,
#  'required': 214,
#  'haunting': 106,
#  'given': 1956,
#  'computer': 590,
#  'treatment': 222,
#  'courtesy': 38,
#  'st': 374,
#  'class': 820,
#  'turner': 100,
#  'showed': 432,
#  'promise': 274,
#  'jan': 60,
#  'de': 570,
#  'bont': 16,
#  'speed': 242,
#  'produced': 550,
#  'string': 156,
#  'budget': 2360,
#  'garbage': 776,
#  'twister': 24,
#  'actor': 2370,
#  'superfluous': 56,
#  'type': 1094,
#  'seem': 2294,
#  'realize': 660,
#  'liam': 44,
#  'neeson': 32,
#  'cathrine': 4,
#  'zeta': 66,
#  'jones': 442,
#  'act': 1458,
#  'wish': 916,
#  'anywhere': 358,
#  'lili': 20,
#  'attempt': 1470,
#  'add': 886,
#  'proceedings': 102,
#  'whatever': 920,
#  'might': 3316,
#  'unknown': 256,
#  'feels': 826,
#  'half': 2684,
#  'missing': 630,
#  'events': 718,
#  'ghosts': 214,
#  'rhyme': 58,
#  'story': 10420,
#  'ends': 1018,
#  'unsatisfying': 76,
#  'event': 334,
#  'meant': 682,
#  'wrap': 80,
#  'previous': 626,
#  'inanity': 12,
#  'screen': 2376,
#  'service': 190,
#  'instead': 2958,
#  'sake': 340,
#  'picture': 1302,
#  'intentions': 212,
#  'bacon': 88,
#  'scientist': 456,
#  'test': 238,
#  'theory': 220,
#  'invisibility': 34,
#  'shue': 28,
#  'usual': 852,
#  'apart': 648,
#  'typical': 686,
#  'thriller': 756,
#  'filmed': 740,
#  'soundstage': 20,
#  'special': 2204,
#  'galore': 34,
#  'minus': 108,
#  'kind': 3078,
#  'humour': 360,
#  'wit': 200,
#  'soul': 366,
#  'waste': 2718,
#  'watching': 5280,
#  'audiocassette': 2,
#  'tape': 200,
#  'delancie': 2,
#  'invisible': 202,
#  'man': 5034,
#  'starring': 398,
#  'leonard': 144,
#  'nimoy': 22,
#  'hg': 14,
#  'wells': 80,
#  'served': 174,
#  'unlike': 390,
#  'mess': 1082,
#  'chose': 234,
#  'score': 820,
#  'imdb': 880,
#  'lot': 3784,
#  'poor': 2962,
#  'taste': 460,
#  'someone': 2982,
#  'fixing': 26,
#  'disappointment': 636,
#  'stupid': 2856,
#  'far': 3240,
#  'fetched': 108,
#  'title': 1656,
#  'summary': 222,
#  'plot': 8310,
#  'felt': 1668,
#  'cool': 980,
#  'snakes': 124,
#  'plane': 372,
#  'crazy': 684,
#  'start': 1912,
#  'biting': 64,
#  'stuff': 1346,
#  'unoriginal': 148,
#  'cgi': 482,
#  'cut': 1260,
#  'corners': 32,
#  'mind': 1980,
#  'recommend': 1338,
#  'anyone': 2836,
#  'acting': 8112,
#  'unbelievable': 678,
#  'stereo': 38,
#  'types': 262,
#  'sum': 208,
#  'stay': 944,
#  'deceives': 6,
#  'line': 2036,
#  'laughable': 768,
#  'cringe': 160,
#  'zombie': 1020,
#  'nation': 128,
#  'implies': 54,
#  'hoard': 2,
#  'zombies': 816,
#  'six': 368,
#  'total': 874,
#  'categorised': 6,
#  'due': 842,
#  'introduction': 156,
#  'cheesy': 812,
#  'music': 2636,
#  'attack': 536,
#  'actually': 4900,
#  'human': 1190,
#  'beings': 100,
#  'difference': 362,
#  'looks': 3056,
#  'la': 510,
#  'roux': 2,
#  'video': 2086,
#  'chance': 896,
#  'buy': 744,
#  'copy': 518,
#  'brain': 696,
#  'bought': 476,
#  'ignorance': 92,
#  'thought': 3596,
#  'peter': 632,
#  'jackson': 250,
#  'stood': 94,
#  'dire': 208,
#  'promotes': 14,
#  'stare': 80,
#  'middle': 1026,
#  'distance': 118,
#  'taking': 928,
#  'lessons': 132,
#  'joey': 68,
#  'tribbiani': 2,
#  'stick': 628,
#  'plus': 672,
#  'confused': 436,
#  'sat': 434,
#  'dream': 510,
#  'frustration': 94,
#  'sets': 770,
#  'within': 754,
#  'avoid': 1286,
#  'plague': 162,
#  'young': 2634,
#  'carry': 364,
#  'limb': 14,
#  'regeneration': 8,
#  'overbearing': 52,
#  'mother': 1258,
#  'convinced': 228,
#  'murdered': 304,
#  'monitoring': 8,
#  'progress': 82,
#  'evil': 1576,
#  'purposes': 84,
#  'uses': 442,
#  'reptilian': 18,
#  'dna': 36,
#  'extracts': 16,
#  'large': 526,
#  'creature': 444,
#  'arm': 202,
#  'conveniently': 90,
#  'ripped': 224,
#  'injects': 26,
#  'formula': 250,
#  'grows': 108,
#  'murderous': 90,
#  'admittedly': 158,
#  'severed': 98,
#  'ties': 90,
#  'pretty': 4230,
#  'grotesque': 78,
#  'rest': 2044,
#  'behaving': 48,
#  'snake': 152,
#  'deal': 602,
#  'mediocre': 580,
#  'climax': 420,
#  'silly': 1202,
#  'inept': 290,
#  'incoherent': 262,
#  'supernatural': 200,
#  'college': 598,
#  'student': 436,
#  'cassie': 76,
#  'melissa': 68,
#  'sagemiller': 22,
#  'constant': 290,
#  'victim': 448,
#  'hallucinations': 46,
#  'nightmares': 110,
#  'accident': 320,
#  'claims': 246,
#  'boyfriend': 454,
#  'sean': 294,
#  'casey': 30,
#  'affleck': 102,
#  'begin': 760,
#  'importance': 82,
#  'sort': 1680,
#  'actual': 876,
#  'entertainment': 804,
#  'value': 634,
#  'particular': 584,
#  'unconvincing': 324,
#  'promote': 88,
#  'joke': 968,
#  'scares': 228,
#  'songs': 756,
#  'earth': 982,
#  'project': 606,
#  'green': 382,
#  'light': 764,
#  'writer': 1262,
#  'steve': 432,
#  'carpenter': 134,
#  'discernible': 56,
#  'vision': 238,
#  'talent': 1026,
#  'conclusion': 508,
#  'whole': 3536,
#  'alleged': 84,
#  'killer': 1830,
#  'watched': 2284,
#  'pure': 488,
#  'tedium': 68,
#  'saw': 2950,
#  'box': 730,
#  'cover': 690,
#  'stretched': 116,
#  'photography': 328,
#  'scwarz': 2,
#  'ft': 34,
#  'feet': 252,
#  'tall': 136,
#  'fault': 278,
#  'rating': 1082,
#  'night': 2166,
#  'tucson': 4,
#  'second': 1906,
#  'deck': 34,
#  'cigar': 32,
#  'roll': 310,
#  'hill': 280,
#  'needed': 784,
#  'diversion': 20,
#  'totally': 1534,
#  'enjoyed': 734,
#  'bottle': 88,
#  'merlot': 4,
#  'admit': 638,
#  'truly': 1452,
#  'feel': 2708,
#  'close': 1250,
#  'hitting': 148,
#  'mark': 572,
#  'frantic': 40,
#  'clueless': 102,
#  'comes': 2448,
#  'slow': 1314,
#  'chase': 490,
#  'wow': 538,
#  'safer': 10,
#  'warm': 122,
#  'thankful': 42,
#  'conserved': 2,
#  'gasoline': 22,
#  'less': 2134,
#  'production': 2006,
#  'summer': 308,
#  'months': 234,
#  'anywho': 4,
#  'direction': 1496,
#  'uninspired': 216,
#  'fight': 1134,
#  'sequences': 690,
#  'choreographed': 92,
#  'tightened': 10,
#  'sound': 1484,
#  'delivery': 186,
#  'hit': 936,
#  'kept': 860,
#  'locals': 72,
#  'village': 216,
#  'rather': 2788,
#  'cue': 110,
#  'happening': 424,
#  'lens': 42,
#  'deer': 58,
#  'lights': 144,
#  'smile': 216,
#  'smiling': 52,
#  'columbu': 4,
#  'bet': 264,
#  'heart': 738,
#  'caring': 152,
#  'spirit': 416,
#  'countrymen': 6,
#  'baretta': 8,
#  'island': 660,
#  'lethargic': 38,
#  'x': 352,
#  'hates': 100,
#  'love': 4304,
#  'funny': 4674,
#  'discriminating': 10,
#  'franco': 124,
#  'adding': 158,
#  'addendum': 4,
#  'killing': 874,
#  'hours': 1148,
#  'straight': 1006,
#  'b': 1556,
#  'library': 118,
#  'collection': 278,
#  'check': 782,
#  'sweat': 60,
#  'robert': 764,
#  'z': 138,
#  'dar': 8,
#  'tango': 30,
#  'cash': 300,
#  'bomb': 326,
#  'cop': 734,
#  'discovery': 88,
#  'lame': 1304,
#  'crutches': 10,
#  'ran': 232,
#  'money': 3280,
#  'fire': 684,
#  'credits': 808,
#  'gave': 1256,
#  'overall': 1218,
#  'waiting': 576,
#  'sequel': 1044,
#  'revenge': 592,
#  'montazuma': 2,
#  'mexican': 194,
#  'vacation': 150,
#  'gets': 3428,
#  'sick': 586,
#  'declares': 24,
#  ...}

# %%
wordfreq_df
# Out:
# 1  alan         231
#    rickman       71
#    emma          72
#    thompson      92
#    give        3326
#                ...
#    marfa          1
#    banii          1
#    cristi         1
#    puiu           1
#    selleca        1
# Length: 72181, dtype: int64

# %%
df_new = pd.DataFrame.from_dict(wordfreq, orient="index")

# %%
df_new
# Out:
#                  0
# working        662
# one          26276
# best          4192
# shakespeare    224
# sources         70
# ...            ...
# afleck           2
# repleat          2
# jowls            2
# camora           2
# capiche          2
#
# [53070 rows x 1 columns]

# %%
df_new.to_csv('word_frequency.csv', index=True)
